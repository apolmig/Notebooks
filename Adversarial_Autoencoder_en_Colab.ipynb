# %% [markdown]
# <a href="https://colab.research.google.com/github/apolmig/Notebooks/blob/master/Adversarial_Autoencoder_en_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nibabel
import os
# Out:
# ...
#     100% |████████████████████████████████| 4.2MB 7.3MB/s
# ...
# done
#   Stored in directory: /content/.cache/pip/wheels/46/50/8d/bcb0b8f7c030da5bac1752fbe9cc375cbf5725fa93ba79ad84
# Successfully built nibabel
# ...

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
# !git clone https://github.com/danielcanueto/abide
os.chdir("abide")
# !python3 download_abide_preproc.py -d reho -p cpac -s nofilt_noglobal -o '/content/ABIDE_data'
os.chdir("..")
# Out:
# Cloning into 'abide'...
# remote: Counting objects: 869, done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 869 (delta 13), reused 0 (delta 0), pack-reused 845
# Receiving objects: 100% (869/869), 67.23 MiB | 18.55 MiB/s, done.
# Resolving deltas: 100% (445/445), done.
# No upper age threshold specified
# No lower age threshold specified
# No site specified, using all sites...
# No sex specified, using all sexes...
# Could not find /content/ABIDE_data, creating now...
# ...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/reho/Pitt_0050004_reho.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/reho/Pitt_0050005_reho.nii.gz to download queue...
# Adding https://s3.amazonaws.com/fcp-indi/data/Projects/ABIDE_Initiative/Outputs/cpac/nofilt_noglobal/reho/Pitt_0050006_reho.nii.gz to download queue...
# ...

# %%
# !rm -r Adversarial_Autoencoder
# import os
# !git clone https://github.com/Naresh1318/Adversarial_Autoencoder
# Out:
# rm: cannot remove 'Adversarial_Autoencoder': No such file or directory
# Cloning into 'Adversarial_Autoencoder'...
# remote: Counting objects: 275, done.
# remote: Total 275 (delta 0), reused 0 (delta 0), pack-reused 275
# Receiving objects: 100% (275/275), 9.03 MiB | 10.85 MiB/s, done.
# Resolving deltas: 100% (144/144), done.

# %%
#!python3 Adversarial_Autoencoder/psy_manifold.py --train True
# !python3 Adversarial_Autoencoder/psy_manifold_v2.py --train True
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 2018-06-02 11:04:53.805879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-06-02 11:04:53.806390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
# !python3 Adversarial_Autoencoder/psy_manifold_v2.py --train False
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 2018-06-02 11:23:10.562860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:898] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-06-02 11:23:10.563353: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# ...

# %%
os.chdir('Adversarial_Autoencoder')

# %%
# !python3 adversarial_autoencoder.py
# Out:
# /usr/local/lib/python3.6/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From adversarial_autoencoder.py:13: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# ...

# %%
generate_image_grid(sess, op=decoder_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fcc1fc0a5d2e> in <module>()
# ----> 1 generate_image_grid(sess, op=decoder_image)
#
# NameError: name 'generate_image_grid' is not defined

# %%
os.listdir()
# Out:
# ['datalab', '.ipython', '.rnd', '.cache', '.forever', '.config', '.local']
